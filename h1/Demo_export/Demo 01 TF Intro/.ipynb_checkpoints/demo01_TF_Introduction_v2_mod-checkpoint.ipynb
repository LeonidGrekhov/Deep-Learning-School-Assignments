# %%
import tensorflow as tf

print(tf.__version__)
# Out:
# 2.6.0

# %% [markdown]
# # Tensorflow Variable Examples

# %%
a = tf.constant([[1, 2],
                 [3, 4]])
print(a)
# Out:
# tf.Tensor(
# [[1 2]
#  [3 4]], shape=(2, 2), dtype=int32)

# %%
# Broadcasting support
b = tf.add(a, 1)
print(b)
# Out:
# tf.Tensor(
# [[2 3]
#  [4 5]], shape=(2, 2), dtype=int32)

# %%
# Operator overloading is supported
print(a * b)
# Out:
# tf.Tensor(
# [[ 2  6]
#  [12 20]], shape=(2, 2), dtype=int32)

# %%
# Can specify a data type for tf variables
a = tf.constant(3.0, dtype=tf.float32)
b = tf.constant(4.0, dtype=tf.float32)

c = a+b
print(c)
# Out:
# tf.Tensor(7.0, shape=(), dtype=float32)

# %%
# Use NumPy values
import numpy as np

c = np.multiply(a, b)
print(c)
print(type(c))
# Out:
# 12.0
# <class 'numpy.float32'>

# %%
# Obtain numpy value from a tensor:
print(a.numpy())
print(type(a))
print(type(a.numpy()))
# Out:
# 3.0
# <class 'tensorflow.python.framework.ops.EagerTensor'>
# <class 'numpy.float32'>

# %% [markdown]
# # Simple Neural Network with Keras

# %%
inputs = np.linspace(-2*np.pi, 2*np.pi, 10000)[:, None]
outputs = inputs + 8 * np.random.normal(size=[len(inputs),1])
print(inputs.shape)
print(outputs.shape)
import matplotlib.pyplot as plt
plt.scatter(inputs[:, 0], outputs[:, 0], s=0.1, color='k', marker='o')
# Out:
# (10000, 1)
# (10000, 1)

# %%
# Create a linear model
linear_model = tf.keras.Sequential([tf.keras.layers.Dense(1)])

# %%
# Get results from an untrained model
linear_predictions = linear_model(inputs)
print(linear_predictions)
# Out:
# tf.Tensor(
# [[-4.5939903]
#  [-4.593071 ]
#  [-4.592152 ]
#  ...
#  [ 4.592152 ]
#  [ 4.593071 ]
#  [ 4.5939903]], shape=(10000, 1), dtype=float32)

# %%
# Plot the untrained results
plt.scatter(inputs[:, 0], outputs[:, 0], s=0.1, color='k', marker='o')
plt.plot(inputs[:, 0], linear_predictions[:, 0])

# %%
# Get Loss from library
example_loss = tf.keras.losses.MeanSquaredError()
# Compile the model with an optimizer
linear_model.compile(optimizer='SGD',
                     loss=example_loss,
                     metrics=['mean_squared_error'])

# %%
linear_model.fit(inputs,outputs,epochs=2)
# Out:
# Epoch 1/2
# 313/313 [==============================] - 2s 4ms/step - loss: 64.7874 - mean_squared_error: 64.7874
# Epoch 2/2
# 313/313 [==============================] - 0s 1ms/step - loss: 64.7682 - mean_squared_error: 64.7682

# %%
linear_predict = linear_model.predict(inputs)

# %%
# Plot the trained results
plt.scatter(inputs[:, 0], outputs[:, 0], s=0.1, color='k', marker='o')
plt.plot(inputs[:, 0], linear_predict[:, 0])

# %% [markdown]
# ## Utilizing a more Complecated Example

# %%
# Input data
import numpy as np
inputs = np.linspace(-2*np.pi, 2*np.pi, 10000)[:, None]
outputs = np.sin(inputs) + 0.05 * np.random.normal(size=[len(inputs),1])
print(inputs.shape)
print(outputs.shape)
import matplotlib.pyplot as plt
plt.scatter(inputs[:, 0], outputs[:, 0], s=0.1, color='k', marker='o')
# Out:
# (10000, 1)
# (10000, 1)

# %%
# Create a linear model
linear_model = tf.keras.Sequential([tf.keras.layers.Dense(1,"sigmoid")])

# %%
# Get results from an untrained model
linear_predictions = linear_model(inputs)
print(linear_predictions)
# Out:
# tf.Tensor(
# [[0.996421  ]
#  [0.9964169 ]
#  [0.9964129 ]
#  ...
#  [0.00358713]
#  [0.00358304]
#  [0.00357902]], shape=(10000, 1), dtype=float32)

# %%
# Plot the untrained results
plt.scatter(inputs[:, 0], outputs[:, 0], s=0.1, color='k', marker='o')
plt.plot(inputs[:, 0], linear_predictions[:, 0])

# %%
# Compile the model with an optimizer
linear_model.compile(optimizer='SGD',
                     loss=example_loss,
                     metrics=['mean_squared_error'])
linear_model.fit(inputs,outputs,epochs=2)
linear_predict = linear_model.predict(inputs)
# Out:
# Epoch 1/2
# 313/313 [==============================] - 1s 1ms/step - loss: 0.7013 - mean_squared_error: 0.7013
# Epoch 2/2
# 313/313 [==============================] - 0s 1ms/step - loss: 0.5740 - mean_squared_error: 0.5740

# %%
# Plot the trained results
plt.scatter(inputs[:, 0], outputs[:, 0], s=0.1, color='k', marker='o')
plt.plot(inputs[:, 0], linear_predict[:, 0])

# %% [markdown]
# Basic layer is linear, can change activation to see different outputs

# %% [markdown]
# Arguments when initalizing a dense layer
# tf.keras.layers.Dense(
#     units,
#     activation=None,
#     use_bias=True,
#     kernel_initializer="glorot_uniform",
#     bias_initializer="zeros",
#     kernel_regularizer=None,
#     bias_regularizer=None,
#     activity_regularizer=None,
#     kernel_constraint=None,
#     bias_constraint=None,
#     **kwargs
# )

# %% [markdown]
# Train Example

# %%
inputs
# Out:
# array([[-6.28318531],
#        [-6.28192854],
#        [-6.28067178],
#        ...,
#        [ 6.28067178],
#        [ 6.28192854],
#        [ 6.28318531]])

# %%
# Create a Deep Model
sample_model = tf.keras.Sequential([
                                    tf.keras.layers.Dense(16,activation='sigmoid',input_shape=[1,]),
                                    tf.keras.layers.Dense(16,activation='relu'),
                                    tf.keras.layers.Dense(1)
                                    ])

# %%
# Compile the model with an optimizer
sample_model.compile(optimizer='adam',
                     loss=example_loss,
                     metrics=['mean_squared_error'])

# %%
# Can print out the details of the model after compileing
sample_model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_11 (Dense)             (None, 16)                32
# _________________________________________________________________
# dense_12 (Dense)             (None, 16)                272
# _________________________________________________________________
# dense_13 (Dense)             (None, 1)                 17
# =================================================================
# Total params: 321
# Trainable params: 321
# Non-trainable params: 0
# _________________________________________________________________

# %%
sample_model.fit(inputs,outputs,epochs=5)
# Out:
# Epoch 1/5
# 313/313 [==============================] - 1s 1ms/step - loss: 0.4328 - mean_squared_error: 0.4328
# Epoch 2/5
# 313/313 [==============================] - 0s 1ms/step - loss: 0.3645 - mean_squared_error: 0.3645
# Epoch 3/5
# 313/313 [==============================] - 0s 1ms/step - loss: 0.2815 - mean_squared_error: 0.2815
# Epoch 4/5
# 313/313 [==============================] - 0s 1ms/step - loss: 0.1901 - mean_squared_error: 0.1901
# Epoch 5/5
# 313/313 [==============================] - 0s 1ms/step - loss: 0.1273 - mean_squared_error: 0.1273

# %%
sample_predict = sample_model.predict(inputs)

# %%
# Plot the untrained results
plt.scatter(inputs[:, 0], outputs[:, 0], s=0.1, color='k', marker='o')
plt.plot(inputs[:, 0], sample_predict[:, 0])

# %%
# Create a Deep Model
sample_model_v2 = tf.keras.Sequential([
                                    tf.keras.layers.Dense(32,activation='sigmoid',input_shape=[1,]),
                                    tf.keras.layers.Dense(16,activation='relu'),
                                    tf.keras.layers.Dense(1)
                                    ])

# %%
# Compile the model with an optimizer
sample_model_v2.compile(optimizer='adam',
                     loss=example_loss,
                     metrics=['mean_squared_error'])
sample_model_v2.fit(inputs,outputs,epochs=5)
sample_predict_v2 = sample_model_v2.predict(inputs)
# Out:
# Epoch 1/5
# 313/313 [==============================] - 1s 2ms/step - loss: 0.3497 - mean_squared_error: 0.3497
# Epoch 2/5
# 313/313 [==============================] - 0s 2ms/step - loss: 0.1859 - mean_squared_error: 0.1859
# Epoch 3/5
# 313/313 [==============================] - 0s 1ms/step - loss: 0.1010 - mean_squared_error: 0.1010
# Epoch 4/5
# 313/313 [==============================] - 0s 2ms/step - loss: 0.0768 - mean_squared_error: 0.0768
# Epoch 5/5
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0630 - mean_squared_error: 0.0630

# %%
# Plot the untrained results
plt.scatter(inputs[:, 0], outputs[:, 0], s=0.1, color='k', marker='o')
plt.plot(inputs[:, 0], sample_predict_v2[:, 0])
